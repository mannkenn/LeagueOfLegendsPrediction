# %%
import requests
import time
import random
import pandas as pd

api_key = "RGAPI-dad742de-85d2-4c4f-9beb-8cf48db7de96"
api_url = "https://na1.api.riotgames.com/lol/league-exp/v4/entries/RANKED_SOLO_5x5"


def get_players(rank, division, num_players):
    '''
    Returns summoner names of players with over 100 games played this season from specified rank and division
    '''
    players_url = ("%s/%s/%s?page=2&api_key=%s" % (api_url, rank, division, api_key)
    )
    resp = requests.get(players_url)
    data = resp.json()
    
    # Filter for players with over 100 games played this season
    active_players = [player['summonerName'] for player in data if player['wins'] + player['losses'] > 20]

    
    return active_players[:num_players]


ranks = ['IRON', 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'EMERALD', 'DIAMOND', 'MASTER', 'GRANDMASTER', 'CHALLENGER']
divisions = ['IV', 'III', 'II', 'I']

players = {}
for rank in ranks:
    if rank in ['MASTER', 'GRANDMASTER', 'CHALLENGER']:
        players["%s %s" %(rank,'I')] = (get_players(rank, 'I', 50))
        continue
    for division in divisions:
        players["%s %s" %(rank, division)] = get_players(rank, division, 50)
print(players)

df = pd.DataFrame(players)
# Out:
# {'IRON IV': ['Boogie Tonight', 'lValkyriel', 'wobld', 'lilojb', 'UltiDragons', 'bIkLeila', 'CREAMT3AM', 'PM FØR WINTRADE', 'rhadoo', 'BlùMew', '3nderrr', 'Sleepy Ned', 'Zulu42069', 'Black phoenixX13', 'Techtronics', 'MrCoachR', 'Hello12xd', 'KingBlitz1', 'Dschungelkonig', 'Chinotchi', 'Athena1506', 'Torthicc', 'Valkiriel', 'rydervader', 'oOPrymrybOo', 'Don Rocan', 'BrianTheMadMan', 'kiss the ring', 'SSS Sin Keku', 'RHarris32', 'FreshyBoy24', 'Funny Gaming COO', 'skateandlife09', 'SAND COFF1N', 'VeganGod69', 'SmokeOwl7896', '1800helpmepls', 'Crippledx', 'Mindlezz Enigma', 'Prøfessør Irelia', 'Choogler', 'Alpha Chad Eboy', 'gioo04', 'simpgang', 'Butcher1807', 'DeathByNightfall', 'icegod420', 'robbigfoot6', 'DreadKING555', 'Shikixo'], 'IRON III': ['SeriousVirgo', 'Marraxus101', 'Noxian Assault', 'IDontNoWatIDoing', 'GoGurtYogurt', 'TyeHarb', 'erinatx', 'Outlawkids', 'WHITEDEAD897', 'mogamunzeya', 'AngelofRath', 'loggiicc', 'EmSeaSquared513', 'peterweller1', 'ziggydogwoofwoof', 'SheDo21', 'Gueyte', 'milkspore', 'shafa', 'Desire123456', 'KyoteStarrk', 'Harris9nn', '100KNIGHTM', 'AnothaRedhead', 'Doc427', 'BasilBear02', 'Dont Play Yuumi', 'EezyKILLS', 'FijiOnMyHead', 'scuffedyi', 'FantasticTG', 'getsnaked', 'SassyShuckle', 'Hey its Ouija', 'CaptainHoggy', 'MWals', 'NationalTakeover', 'KujinKrush07', 'CHG Veldora', 'StaticGeeked', 'Senior Onii Chan', 'Zeavos', '1MoriJin', 'Bloodknightv', 'yooooo116', 'Askuzaiii', 'frankyboy2215', 'AnguishBook', 'richeee31', 'MoogleKing1'], 'IRON II': ['nairb82', 'PastelStorms', 'PilatusDr', 'TheBeachedHippo', 'Android Apollo', 'ripemNleavethem', 'DariusQuinn', '4drunkhookers', 'MDBacon', 'UdyrInABush', 'RealMythReaper', 'Trol Koz', 'Agent Kaioken', 'Zayda Senpai', 'Kerinthalas', 'KindredTheGreat', 'IGotCoffee', 'Knokout', 'I7ZZNightmare', 'IssaEsJueves', 'octøber', 'silly goose69420', 'WestD3', 'Shane2415', 'juniorsnipes500', 'Trojan055', 'HeyItsMan', 'Django11', 'Shandlebar', 'Gankato12', 'Potatos Yum', 'ShortyMike', 'dragonrider4555', 'cyb3r anarch', 'Grouldmight', 'NeekoisWifu', 'Ron Xenon', 'Srom93', 'HookersNCrack', 'Aspenski', 'MJR13', 'xXAztecaXx', 'Yas with Sauce', 'Soggy NoodIes', 'HDST Official', 'GPV247', 'Parthevious', 'Umikame', 'JVMathlete', '30k0816'], 'IRON I': ['xBlackOutGaming', 'OneRiserSlip', 'OneLazyDaoist', 'NichoBack', 'CACA MONSTER', 'AxelHazaki', 'Tylina916', 'je210', 'BrokenXuan', 'OSVanH', 'SC00TYPUFFSR', 'StinkyDemon', 'unstablegg', 'DjDude02', 'TheDivineCandy', 'Pieco', 'PROGECTK2', 'Mrden98', 'MurphsGh0st', 'Spank me Pitou', 'buoygenius', '', 'Brette57', 'peachcinnamon62', 'nappyheadryan', 'MightyRiverHorse', 'VeridianApe', 'Histeria', 'agonizeddad', 'Skrynth', 'Stepson is Hard', 'Flaming phoenix7', 'Bim0 El Teamo', 'FormerYuumiMain', 'King of le Filth', 'Brushmegood', 'IamDooblr', 'AspectofEvil', 'Centurion76', 'Ravenhawk26', 'thedarkinlive', 'Chunkmunx', 'BootySuckerr', 'Frww', 'kisanii', 'Tsaeyu', '7312663', 'xbox controller', 'MehdiBest', 'NightProduct12'], 'BRONZE IV': ['A Bronze Klug', 'Snappington', 'K3nnyG', 'mystıc', 'Ziphor1476', 'Kostolom', 'naluart', 'LuckyChewch', 'Litebluwulf', '0CaralhoVoador0', 'SwagMastahhh', 'MrDannyloco', 'KahunaKy', 'Monarch907', 'NotDaVinci', 'Tactic2Seven', 'NotDoot', 'Leaf Erikson', 'SCORPS20', 'Triidxnt', 'Air Jinx', 'Swordwolf9', 'JoEGrAhZ', 'StopRagingg', 'AstralFurry', 'GENERALCHICKEN21', 'ColeTrain1269', 'x Perseus Veil x', 'RunningMaroon', 'Comet52', 'ummmdotdotdot', 'MrChrister', 'planetchancho', 'Torched You', 'Shiberg', 'Stoic Rage', 'DeluxeAir', 'mahss', 'Hgrizz111', 'redowl11376', 'GodKing Od1n', 'GoringGambit', 'MistaBigBoss', 'MKULTRAHUMAN', 'KIIDR', 'Craving a bullet', 'ChinaNo1IG', 'Meowllionaire', 'vUnedited', 'bag alert'], 'BRONZE III': ['Rentedcoffee8', 'Ultrachampion02', 'Curiyy', 'BangTuEsMort', 'songcraft', 'bryckzzz', 'SaguinusImperato', 'DayMan159', 'Birdsaretoxic2', 'lilscruffy JC', 'ReUltraman', 'BozoBowser', 'SmoothFox', 'OH NO A ZED', 'eggeroni', 'pheonixlightning', 'gerg14', 'please', 'Baaju', 'Endless A ...

# %%
df.to_csv('output.txt', sep=',', index=False)
