# %%
import requests
import time
import random
import pandas as pd
import seaborn as sns


# Import summoner names
data = pd.read_csv(r"C:\Users\toirt\LeagueOfLegendsPrediction\data\summoner_names.csv")
df = pd.DataFrame(data)
print(df.shape)
df.head()
# Out:
# (50, 31)
#             IRON IV          IRON III          IRON II           IRON I  \
# 0        Crazyknees    Useless Ginger  GotAStomachAche       LilRambe29
# 1  ScriptsAnonymous  majesticasszebra           FL4K3R  jackferrarri666
# 2       Oberon16099           CountEa       Azurasfire     VenusVerdict
# 3     SantosDaSaint      hamzadaaboul          Osamu03   1tricteemomain
# 4             Š i r        thepurge12      GodOfDawn12     VersaceCosby
#
#        BRONZE IV        BRONZE III        BRONZE II    BRONZE I  \
# 0   Jest The Tip          KriegKMS      DieCatsKing     misha7t
# 1  Hotrodhamster           Auzyman     HalfOurKills      Not HT
# 2   GingerMellon            Ca Man  soggyburnttoast  dawgaholic
# 3        spaceb6     teddy sanders      Quatzlcoatl     OJCOSBY
# 4         sarK35  Show my your TDs      World3edgar   MidAbus3r
#
#        SILVER IV        SILVER III  ...       EMERALD III       EMERALD II  \
# 0     Trigno Kon  IonTheIncredible  ...    THÍCH THÌ FEED         WillMega
# 1       Keemchix        ChildSpork  ...  Promise It Worth         Hoonroro
# 2   Argus Hunter          taooo000  ...         Yoshimaro  gamer girl piss
# 3  FEAR THE LAMB         Parelaxes  ...          BillyQWQ       Terikuruzu
# 4      Kxmi Sama        mikemillan  ...        Popsicle10     Cooldrpepper
#
#       EMERALD I   DIAMOND IV     DIAMOND III        DIAMOND II  \
# 0     Extrovert   EDGFlándre  Leviathan Fang  Maybe I Kiss Men
# 1  GONGGONQICHE  Petr1ch0r00   TC Akan Tamen            Sweets
# 2     WardAkali    Modestsky         Aubreey       Tzuyu Twıce
# 3      For Hana    Níghtmąré            Nuja           DaiCaA6
# 4     andyzizon    haylobkim      EzGamec373    lIlIlIllIlIlIl
#
#          DIAMOND I        MASTER I     GRANDMASTER I CHALLENGER I
# 0     bombtruck457   Loves Vagrant      ThëBeesKnees   weieryuxin
# 1            YoShy       ADCADC123  Quancutengokngek       Spica9
# 2  XxDVRKWH1SP3RxX  Illegal detect          Sasha xo   KatEvolved
# 3             Týph          Pingky  Zeffry Aboujeeni        T0mio
# 4           nakyum       Zeypher69             ARMAO          NaN
#
# [5 rows x 31 columns]

# %%
rank_distribution = {
    'IRON IV': 0.03,
    'IRON III': 0.022,
    'IRON II': 0.011,
    'IRON I': 0.03,
    'BRONZE IV': 0.053,
    'BRONZE III': 0.047,
    'BRONZE II': 0.045,
    'BRONZE I': 0.036,
    'SILVER IV': 0.057,
    'SILVER III': 0.046,
    'SILVER II': 0.043,
    'SILVER I': 0.035,
    'GOLD IV': 0.064,
    'GOLD III': 0.048,
    'GOLD II': 0.048,
    'GOLD I': 0.04,
    'PLATINUM IV': 0.071,
    'PLATINUM III': 0.048,
    'PLATINUM II': 0.041,
    'PLATINUM I': 0.031,
    'EMERALD IV': 0.06,
    'EMERALD III': 0.029,
    'EMERALD II': 0.02,
    'EMERALD I': 0.012,
    'DIAMOND IV': 0.021,
    'DIAMOND III': 0.01,
    'DIAMOND II': 0.0064,
    'DIAMOND I': 0.0035,
    'MASTER I': 0.0042,
    'GRANDMASTER I': 0.0006,
    'CHALLENGER I': 0.00023
}

# %%
# Need to filter this data to represent playerbase
def player_distribution(distribution, data):
    '''
    Takes in players and returns a list with players proportional to distribution of ranks
    '''
    total_players = (data.shape[0]*data.shape[1])/2 # split amount of players in half to account for percents greater than 3%
    names = []
    for key, value in distribution.items():
        if key in ['MASTER I', 'GRANDMASTER I', 'CHALLENGER I']: # only include 1 player from highest ranks
            names.append(df[key][:1])
        else:
            names.append(df[key][:round(value*total_players)])
    return names
                                          
                     
names = player_distribution(rank_distribution, df)
names_df = pd.DataFrame(names).T
names_df.head()
# Out:
#       IRON IV         IRON III          IRON II         IRON I      BRONZE IV  \
# 0      rhadoo  Soggywaffles196          nairb82   OneRiserSlip  A Bronze Klug
# 1      BlùMew       togaparty1     PastelStorms  OneLazyDaoist    Snappington
# 2     3nderrr     SeriousVirgo  TheBeachedHippo      NichoBack         K3nnyG
# 3  Sleepy Ned      Marraxus101   Android Apollo   CACA MONSTER         mystıc
# 4   Zulu42069   Noxian Assault  ripemNleavethem     AxelHazaki     Ziphor1476
#
#         BRONZE III    BRONZE II         BRONZE I        SILVER IV  \
# 0    Rentedcoffee8  MattRock314     Ajapril34487       DivineRune
# 1  Ultrachampion02  DioBrando57          Zeqhyrs     EPICGAMER429
# 2           Curiyy     cashen95          Spandex     BamBam124684
# 3     BangTuEsMort    bigddom21  Into the Spiral  TentacleQueenie
# 4        songcraft     N0ctis97             Twïn          Therak1
#
#         SILVER III  ...      EMERALD III       EMERALD II       EMERALD I  \
# 0      Starlight03  ...      sneakypatty           Eonirs      Shirøyasha
# 1            Masön  ...   YOUR PAPA CHOW     haramslayerr     No Name PLS
# 2      MagikCungFu  ...  Team Player Ted          Vmikael        ImDrippy
# 3  boythekiller102  ...  TAO BAN AD M IM  RuneScape Lucky          Makrae
# 4      Trichiosoma  ...       serfmirage       Shimadacat  chang yuanying
#
#        DIAMOND IV     DIAMOND III        DIAMOND II   DIAMOND I MASTER I  \
# 0     Broken Feng            La1n       THICCDUMPER      rovref   Kaleos
# 1          PMA JG       Btown TOP   SylphieRoxyEris  Warbil Fan      NaN
# 2        DmnSword     TaxEvader33            Mimick    Pika1106      NaN
# 3  OceanGate FFed           Hòrse         O1de Town         NaN      NaN
# 4        Moonchaa  Jasondingduong  RagingRookie5757         NaN      NaN
#
#   GRANDMASTER I    CHALLENGER I
# 0    ScaryJerry  jin tui wei gu
# 1           NaN             NaN
# 2           NaN             NaN
# 3           NaN             NaN
# 4           NaN             NaN
#
# [5 rows x 31 columns]

# %%
names_df.to_csv('final_summoner_names.csv', sep=',', index=False) # Export to CSV
