# %%
import requests
import time
import random
import pandas as pd
import seaborn as sns


# Import summoner names
data = pd.read_csv(r"C:\Users\toirt\LeagueOfLegendsPrediction\notebooks\output.txt")
df = pd.DataFrame(data)
print(df.shape)
df.head()
# Out:
# (50, 31)
#       IRON IV         IRON III          IRON II         IRON I      BRONZE IV  \
# 0      rhadoo  Soggywaffles196          nairb82   OneRiserSlip  A Bronze Klug
# 1      BlùMew       togaparty1     PastelStorms  OneLazyDaoist    Snappington
# 2     3nderrr     SeriousVirgo  TheBeachedHippo      NichoBack         K3nnyG
# 3  Sleepy Ned      Marraxus101   Android Apollo   CACA MONSTER         mystıc
# 4   Zulu42069   Noxian Assault  ripemNleavethem     AxelHazaki     Ziphor1476
#
#         BRONZE III    BRONZE II         BRONZE I        SILVER IV  \
# 0    Rentedcoffee8  MattRock314     Ajapril34487       DivineRune
# 1  Ultrachampion02  DioBrando57          Zeqhyrs     EPICGAMER429
# 2           Curiyy     cashen95          Spandex     BamBam124684
# 3     BangTuEsMort    bigddom21  Into the Spiral  TentacleQueenie
# 4        songcraft     N0ctis97             Twïn          Therak1
#
#         SILVER III  ...      EMERALD III       EMERALD II       EMERALD I  \
# 0      Starlight03  ...      sneakypatty           Eonirs      Shirøyasha
# 1            Masön  ...   YOUR PAPA CHOW     haramslayerr     No Name PLS
# 2      MagikCungFu  ...  Team Player Ted          Vmikael        ImDrippy
# 3  boythekiller102  ...  TAO BAN AD M IM  RuneScape Lucky          Makrae
# 4      Trichiosoma  ...       serfmirage       Shimadacat  chang yuanying
#
#        DIAMOND IV     DIAMOND III        DIAMOND II   DIAMOND I  \
# 0     Broken Feng            La1n       THICCDUMPER      rovref
# 1          PMA JG       Btown TOP   SylphieRoxyEris  Warbil Fan
# 2        DmnSword     TaxEvader33            Mimick    Pika1106
# 3  OceanGate FFed           Hòrse         O1de Town      Scanty
# 4        Moonchaa  Jasondingduong  RagingRookie5757    Candcace
#
#          MASTER I GRANDMASTER I     CHALLENGER I
# 0          Kaleos    ScaryJerry   jin tui wei gu
# 1  Montage Farmer    coolsalajr        IamaNewby
# 2          Aatrox      TriplêAJ              NaN
# 3     WisedLegacy  rat in house        Yonedaime
# 4      PresEvoker    Hiccup1357  Space Excalibur
#
# [5 rows x 31 columns]

# %%
rank_distribution = {
    'IRON IV': 0.03,
    'IRON III': 0.022,
    'IRON II': 0.011,
    'IRON I': 0.03,
    'BRONZE IV': 0.053,
    'BRONZE III': 0.047,
    'BRONZE II': 0.045,
    'BRONZE I': 0.036,
    'SILVER IV': 0.057,
    'SILVER III': 0.046,
    'SILVER II': 0.043,
    'SILVER I': 0.035,
    'GOLD IV': 0.064,
    'GOLD III': 0.048,
    'GOLD II': 0.048,
    'GOLD I': 0.04,
    'PLATINUM IV': 0.071,
    'PLATINUM III': 0.048,
    'PLATINUM II': 0.041,
    'PLATINUM I': 0.031,
    'EMERALD IV': 0.06,
    'EMERALD III': 0.029,
    'EMERALD II': 0.02,
    'EMERALD I': 0.012,
    'DIAMOND IV': 0.021,
    'DIAMOND III': 0.01,
    'DIAMOND II': 0.0064,
    'DIAMOND I': 0.0035,
    'MASTER I': 0.0042,
    'GRANDMASTER I': 0.0006,
    'CHALLENGER I': 0.00023
}
# Out:
# 1550

# %%
# Need to filter this data to represent playerbase
def player_distribution(distribution, data):
    '''
    Takes in players and returns a list with players proportional to distribution of ranks
    '''
    total_players = (data.shape[0]*data.shape[1])/2 # split amount of players in half to account for percents greater than 3%
    names = []
    for key, value in distribution.items():
        if key in ['MASTER I', 'GRANDMASTER I', 'CHALLENGER I']: # only include 1 player from highest ranks
            names.append(df[key][:1])
        else:
            names.append(df[key][:round(value*total_players)])
    return names
                     
                     
                     
names = player_distribution(rank_distribution, df)
# names_df = pd.DataFrame(names).T
# names_df.head()
# Out:
# [0               rhadoo
# 1               BlùMew
# 2              3nderrr
# 3           Sleepy Ned
# 4            Zulu42069
# 5     Black phoenixX13
# 6          Techtronics
# 7             MrCoachR
# 8            Hello12xd
# 9           KingBlitz1
# 10      Dschungelkonig
# 11           Chinotchi
# 12          Athena1506
# 13            Torthicc
# 14           Valkiriel
# 15          rydervader
# 16         oOPrymrybOo
# 17           Don Rocan
# 18      BrianTheMadMan
# 19       kiss the ring
# 20        SSS Sin Keku
# 21           RHarris32
# 22         FreshyBoy24
# Name: IRON IV, dtype: object, 0      Soggywaffles196
# 1           togaparty1
# 2         SeriousVirgo
# 3          Marraxus101
# 4       Noxian Assault
# 5     IDontNoWatIDoing
# 6         GoGurtYogurt
# 7              TyeHarb
# 8              erinatx
# 9           Outlawkids
# 10        WHITEDEAD897
# 11         mogamunzeya
# 12         AngelofRath
# 13            loggiicc
# 14     EmSeaSquared513
# 15        peterweller1
# 16    ziggydogwoofwoof
# Name: IRON III, dtype: object, 0            nairb82
# 1       PastelStorms
# 2    TheBeachedHippo
# 3     Android Apollo
# 4    ripemNleavethem
# 5        DariusQuinn
# 6      4drunkhookers
# 7            MDBacon
# 8        UdyrInABush
# Name: IRON II, dtype: object, 0       OneRiserSlip
# 1      OneLazyDaoist
# 2          NichoBack
# 3       CACA MONSTER
# 4         AxelHazaki
# 5          Tylina916
# 6              je210
# 7         BrokenXuan
# 8             OSVanH
# 9       SC00TYPUFFSR
# 10       StinkyDemon
# 11        unstablegg
# 12          DjDude02
# 13    TheDivineCandy
# 14             Pieco
# 15        Ehecatl338
# 16         PROGECTK2
# 17           Mrden98
# 18       MurphsGh0st
# 19    Spank me Pitou
# 20        buoygenius
# 21               NaN
# 22          Brette57
# Name: IRON I, dtype: object, 0        A Bronze Klug
# 1          Snappington
# 2               K3nnyG
# 3               mystıc
# 4           Ziphor1476
# 5             Kostolom
# 6              naluart
# 7          LuckyChewch
# 8          Litebluwulf
# 9      0CaralhoVoador0
# 10        SwagMastahhh
# 11         MrDannyloco
# 12            KahunaKy
# 13          Monarch907
# 14          NotDaVinci
# 15        Tactic2Seven
# 16             NotDoot
# 17        Leaf Erikson
# 18            SCORPS20
# 19            Triidxnt
# 20            Air Jinx
# 21          Swordwolf9
# 22            JoEGrAhZ
# 23         StopRagingg
# 24         AstralFurry
# 25    GENERALCHICKEN21
# 26       ColeTrain1269
# 27    x Perseus Veil x
# 28       RunningMaroon
# 29             Comet52
# 30       ummmdotdotdot
# 31          MrChrister
# 32       planetchancho
# 33         Torched You
# 34             Shiberg
# 35          Stoic Rage
# 36           DeluxeAir
# 37               mahss
# 38           Hgrizz111
# 39         redowl11376
# 40        GodKing Od1n
# Name: BRONZE IV, dtype: object, 0        Rentedcoffee8
# 1      Ultrachampion02
# 2               Curiyy
# 3         BangTuEsMort
# 4            songcraft
# 5             bryckzzz
# 6     SaguinusImperato
# 7            DayMan159
# 8       Birdsaretoxic2
# 9        lilscruffy JC
# 10          ReUltraman
# 11          BozoBowser
# 12           SmoothFox
# 13         OH NO A ZED
# 14            eggeroni
# 15    pheonixlightning
# 16              gerg14
# 17              please
# 18               Baaju
# 19    Endless Avocados
# 20         that1girl18
# 21      MoonGoddessXIV
# 22         pellmonster
# 23        iplayleague3
# 24             Vitdarr
# 25           theJGrimm
# 26         voidshell16
# 27           Zeppilozt
# 28         texastrev24
# 29            Kyrieeee
# 30      DemonLordMicah
# 31          Catriarchy
# 32              VIP KO
# 33      Gyufluffypanda
# 34    DontPeeInTheWind
# 35            Kareen23
# Name: BRONZE III, dtype: object, 0          MattRock314
# 1          DioBrando57
# 2             cashen95
# 3            bigddom21
# 4             N0ctis97
# 5              GGfrens
# 6      SentientGenesis
# 7             boochiie
# 8     Buckshot Stanley
# 9            CNxDragon
# 10     TH3R34LD1RTYD4N
# 11             Gauldun
# 12             raskaal
# 13              PCRIII
# 14         Kenpachi728
# 15    GrindrsNightmare
# 16           will23333
# 17               Yebii
# 18          beefmouzer
# 19         pink garden
# 20              EazyCG
# 21           Colachopa
# 22         Snail Lover
# 23    Moist For Darius
# 24    VelociRaptor1234
# 25           MemeGod26
# 26          FS Huntzie
# 27        MasianNation
# 28              Otouto
# 29          BoopinBats
# 30        TheChihuahua
# 31             lilhugo
# 32       MnS DracerRen
# 33       Senor Dibbles
# 34       AwwYeahRawnie
# Name: BRONZE II, dtype: object, 0        Ajapril34487
# 1             Zeqhyrs
# 2             Spandex
# 3     Into the Spiral
# 4                Twïn
# 5          Malgoros12
# 6        shadowxyoshi
# 7           IsThatMud
# 8            Linkace1
# 9           Trimthump
# 10      Shortppl4life
# 11           Baowow50
# 12       Imgonnakms00
# 13     honestlykimchi
# 14    LittleArcticFox
# 15        Ch1pSky1ark
# 16            SN0Wowl
# 17       1XXXICHIBAN1
# 18          AndImwack
# 19            Jarcrow
# 20           kb5i7017
# 21     Bias Hopeworld
# 22        Chasin Tail
# 23       odinsfantasy
# 24           4GOOD0NO
# 25          Voltspyke
# 26          Pr0ph3ts1
# 27            BR0FISH
# Name: BRONZE I, dtype: object, 0          DivineRune
# 1        EPICGAMER429
# 2        BamBam124684
# 3     TentacleQueenie
# 4             Therak1
# 5          ZanerosGCM
# 6           Granfatha
# 7      WinterQueen106
# 8     LoLGetRektSon13
# 9           NomadicOG
# 10        Fine Whines
# 11                NaN
# 12        IamSquiddly
# 13          ghizzle94
# 14           KUNNINJA
# 15              Jiruo
# 16           Chraso58
# 17      IKillYouFirst
# 18       PandaCorn151
# 19           Neo DOOM
# 20            Slothii
# 21              Shącó
# 22          First rat
# 23      PandaUppercut
# 24            TRAPPYJ
# 25      lolmasterssun
# 26           VaIentin
# 27            Hellcat
# 28           just mii
# 29        AkwardDoggo
# 30          TSW Lucid
# 31        Necrobeliac
# 32       KhadaPostman
# 33      HypnoticAngel
# 34             Yoshii
# 35      AKA Giant Dog
# 36      DaJuicyNugget
# 37         N1gChamp79
# 38            Kelitar
# 39      xOxFuriousxOx
# 40       margonautica
# 41       DragonZenith
# 42        hughhefnerr
# 43             Ugoomi
# Name: SILVER IV, dtype: object, 0          Starlight03
# 1                Masön
# 2          MagikCungFu
# 3      boythekiller102
# 4          Trichiosoma
# 5           IzayBoiZay
# 6              Rallane
# 7               Turbøø
# 8            nanikitty
# 9              Ukimbat
# 10             IGiotto
# 11     Int4DarkHarvest
# 12            TheGundy
# 13                Gøjo
# 14               Etrii
# 15            smiled1k
# 16       mysteryguy123
# 17            Addicked
# 18    Mecha Babel Mk 2
# 19              xdmerc
# 20            Karalulu
# 21            foxarius
# 22         salmonmusic
# 23            Seaminaj
# 24            Greymïst
# 25           Hikari549
# 26         Emperor FUF
# 27        Reity Eleven
# 28              1n23rt
# 29         Dravens Són
# 30         HikariMitsu
# 31         Autumngales
# 32    1AbraTeleported1
# 33         Poppy Chúlo
# 34     TheQueensSancho
# 35              Ieinad
# Name: SILVER III, dtype: object, 0          xSlayer442x
# 1            OhSoCLean
# 2        Darkfrost1415
# 3               Aksyel
# 4            SacredOaf
# 5            Cyclopian
# 6        TheGreenBeans
# 7      Abysmal Wendigo
# 8             Polarean
# 9            Patronice
# 10          BabySharks
# 11              Kyrodu
# 12          AJ Hammada
# 13         JIZMOD XVII
# 14        LilD1cckgirl
# 15       Vaibhav Patel
# 16            SnowyLoL
# 17            Berseerk
# 18              IMdida
# 19         A Red Widow
# 20          rexho trex
# 21           Valkyriin
# 22                Jªkë
# 23            shapa342
# 24          Pinehapple
# 25    Unfortunate4uall
# 26          Antispawnz
# 27       PenguinPlaya6
# 28           Chadivito
# 29    A Daedric Prince
# 30            hanamiYO
# 31      ßløød ØverLørd
# 32            Liontale
# Name: SILVER II, dtype: object, 0            King Dill
# 1            DonaldI2I
# 2          Silv3rfruit
# 3         ItsMeLuigi69
# 4      AlanButUnhinged
# 5         Fairladyz333
# 6           NomnomSnek
# 7              Mrpoka1
# 8         FreedomLunch
# 9          Punch Nazís
# 10          Soulwrench
# 11                Poen
# 12            Abduskii
# 13             Xeno404
# 14            Hanthree
# 15             airpath
# 16           lemurpelt
# 17             lisette
# 18          ßilllerina
# 19    I Like Your Body
# 20           GM JunSik
# 21        Angel is Fat
# 22          TonyySuckz
# 23             SaUcESS
# 24              Zezima
# 25       tandythemandy
# 26        Pimp Kakashi
# Name: SILVER I, dtype: object, 0               DUBW1Z
# 1                Wyätt
# 2     ALEXMASTER101010
# 3     Jhamburgr Jheþer
# 4           Tinmonkey1
# 5              DaddyLD
# 6             Shr00udy
# 7        GankByJoeMama
# 8            Lean Beef
# 9          TimelessDbz
# 10           SwaggyLee
# 11        PaiDuSeuBebe
# 12      DamonSaIvatore
# 13       JustAsianMatt
# 14             max pan
# 15          rawrzard21
# 16       flown the sun
# 17       tripleS Xinyu
# 18       Im sane again
# 19           Cbossc123
# 20           BabyCakey
# 21               SKTom
# 22         Cat Stealer
# 23          GORBORELEN
# 24          hwajangsil
# 25        TeamShortBus
# 26           Nhocdevil
# 27         Joecrazy117
# 28      reclusivehuman
# 29    Votedemocrat2024
# 30         Meerkat5572
# 31               Enoms
# 32              BLKLAN
# 33        insane dream
# 34                 Ùsl
# 35           OoshJoosh
# 36      MR Snows Ghost
# 37                Lan0
# 38           Yuhangism
# 39        Lordstark696
# 40            wuzzup47
# 41           IcedPaper
# 42    dujikbabistumbir
# 43         Deesilsnarf
# 44        DerrangedDad
# 45            Santatsu
# 46    Why My Supp Suck
# 47             Henehoe
# 48            Strehlow
# 49    Chunchunmaru2099
# Name: GOLD IV, dtype: object, 0         MoonMorrigan
# 1         NYC Kevin888
# 2              Alainxz
# 3         TheTopFather
# 4         KrumpuSChisG
# 5              weesee5
# 6       toplaneendgame
# 7            Thicbacon
# 8              EDO ONE
# 9                 fril
# 10      iiiTsuuKasaiii
# 11        OOOOO000000F
# 12    BasicallyAfrican
# 13          iplayadc13
# 14            CF Gauss
# 15    MgnesiumChloride
# 16          yeobosaeyo
# 17    SmegmaGame2strng
# 18        backspace707
# 19            Zndrsplt
# 20            GhostlyV
# 21    UnicornNinja exe
# 22              Spyiek
# 23           One Thicc
# 24       WaIuigi Judah
# 25           AftërLyfë
# 26        RyZe Depolox
# 27              Jasvic
# 28              Makisu
# 29             Pidgenn
# 30             0rmonix
# 31           Samureiii
# 32       gweiloinvader
# 33               Xymph
# 34        Greenhawks45
# 35         Snow Rising
# 36             Frylock
# Name: GOLD III, dtype: object, 0                 Âxêl
# 1           T1NG light
# 2            Dreamer35
# 3            Disttance
# 4         VIETNAMGAMER
# 5               Alluré
# 6              Dusty72
# 7            HHSCobalt
# 8            Kharon IV
# 9               Zoínks
# 10             denzb13
# 11           ICURRENTI
# 12      tall coque guy
# 13          NotRashaad
# 14            Riseling
# 15             Elevven
# 16         m14sniper66
# 17             Tenkaen
# 18        MonkeyBrians
# 19         SleeepyStar
# 20        HaoleNetwork
# 21             RATGIRŁ
# 22           Our Marks
# 23               0ZzZ0
# 24           krevenixa
# 25              Alpha0
# 26    DontTypeDontCare
# 27     lowercase three
# 28      iwasamistake02
# 29        BellTheSquid
# 30        Denise Buddy
# 31            Antìdote
# 32          drfunTiMeZ
# 33             GAGESTR
# 34               Roshu
# 35        LKGN juceppe
# 36        ShnozTrocity
# Name: GOLD II, dtype: object, 0          aquaticruin
# 1              Kahloon
# 2            shinylyte
# 3     Toùch My Lantern
# 4              ASALAD2
# 5     FRIEDCHICKENKING
# 6              LossGun
# 7             tkdubs15
# 8           Myrmidon71
# 9        BlooodyAlex33
# 10               Ratul
# 11            Casa Ole
# 12            Eli Time
# 13             Zireael
# 14                vjdm
# 15      cuddlebear9000
# 16         Smokin Poop
# 17        BenDover6911
# 18            ILLUSEEN
# 19               csx11
# 20                7890
# 21         Justinscake
# 22      TheBigKahunaaa
# 23      wontonsoup0456
# 24          DingggooJR
# 25                Lính
# 26             rell jg
# 27            R1ukLord
# 28         Tetsuki5603
# 29            Zensiddy
# 30            skełeton
# Name: GOLD I, dtype: object, 0             zared123
# 1     I decide not you
# 2               Aestra
# 3           timein8tor
# 4              JL Payn
# 5              GBRosee
# 6             evasivee
# 7              Catfloo
# 8       GalaxyBandit19
# 9         VuseOriginal
# 10          TRŸNDÅMÊRÉ
# 11           Kurtidabs
# 12            HTTP 418
# 13     TheyCallMeClork
# 14           XayahˆCat
# 15             himilp1
# 16       BadfBoyfriend
# 17       LambPilafBowl
# 18                 Nîl
# 19              AcooZi
# 20                Zané
# 21      I DIE YOU LOSE
# 22       Kabul Airport
# 23             Sirwhip
# 24              Dfjuvl
# 25      IBLUECARDMXLFS
# 26              AZLEUN
# 27             KaiJhin
# 28         yokedasmoke
# 29           ayo relax
# 30          McDondalds
# 31            InnerWar
# 32      1 800 Mattress
# 33         Vastaya IRL
# 34          I will afk
# 35      IAMYOURWILDDAD
# 36           yoyofryyo
# 37     W h e e Z e e Y
# 38     Zhe ba you shen
# 39       ABugsLife9865
# 40      ClovesofClives
# 41              zalmon
# 42            mangoees
# 43       H4rd No TiLLT
# 44             Dodger0
# 45              Bissmo
# 46        Komfort King
# 47        kitten w bpd
# 48               DHL63
# 49     ClearlyFakeNews
# Name: PLATINUM IV, dtype: object, 0            Ted Cundy
# 1         smegma steve
# 2     Powerful Dragon2
# 3            easy path
# 4          abedejong52
# 5       IntingAutofill
# 6            the loach
# 7      LilRob Miss her
# 8           fireninja0
# 9      BoxofShac0lates
# 10      student pilot2
# 11           obsessıve
# 12     Omarbakkour2001
# 13        ItsAMagikarp
# 14    Nanjing DuckKing
# 15          Poppytoad7
# 16        just soo soo
# 17     You are DumbDog
# 18        bagelcreator
# 19           Slzzpless
# 20             Ashamed
# 21              Sleiii
# 22         El Rikimaru
# 23            Wenwen56
# 24              Buntou
# 25          StreamFunk
# 26          petitmulet
# 27       saffron roses
# 28              jamm3y
# 29       CHR0ME HEARTS
# 30              Cinono
# 31           ETSETSETS
# 32     hot demon mommy
# 33     MacabreMars5317
# 34              Txddeh
# 35              Yatara
# 36             BDMarky
# Name: PLATINUM III, dtype: object, 0               p8107
# 1               Têddy
# 2         StinkyBallz
# 3       ShadowRaids27
# 4              SirMRC
# 5               Ąsuka
# 6             AaPpLe6
# 7      DUALGREATSWORD
# 8          1nsightfu1
# 9          mlgdoge131
# 10           SV Numbz
# 11    ESTROGEN ABUSER
# 12             Jæger2
# 13        DarkTrist3m
# 14      UselessPoison
# 15      LazerChickenn
# 16             Flanet
# 17        OG Dummkopf
# 18               HYL4
# 19     KatarinaCitcat
# 20                rWa
# 21    Sauced Up Kebab
# 22       DecayingBoot
# 23               Ahfa
# 24        INTING IVAN
# 25      VisualLearner
# 26            Knoxicc
# 27          dingle789
# 28           chrismnz
# 29       MonstroKid13
# 30         Fed Feeder
# 31         funktasty0
# Name: PLATINUM II, dtype: object, 0           Sidesteper
# 1         MooMooMilk69
# 2      RainbowThunder7
# 3            SgSgamer1
# 4                slrpp
# 5            maroplyer
# 6            CrabbyGod
# 7       Winter Kitsune
# 8         ShatteredAxe
# 9      Subhuman Sarili
# 10     Garfields belly
# 11             heaIpIz
# 12          ExpertoDan
# 13            PinkGaSX
# 14      Im Mordekaiser
# 15       Rakakakakakan
# 16    T1 Keria fangirl
# 17         thinshin123
# 18             adriyun
# 19          NeopoIitan
# 20          ARamenBowl
# 21             Rammuel
# 22            rockelle
# 23             VKaiser
# Name: PLATINUM I, dtype: object, 0     lIIllIlIIlIllIIl
# 1         Penguinlords
# 2            Ancâlagon
# 3               Synpai
# 4          SpoopyChina
# 5      Xeraths Scripts
# 6          Mickey99876
# 7                 DWU1
# 8        AceFighter101
# 9             bokuto62
# 10    bunkybouncebrude
# 11               Lauru
# 12     To Teemo Or Not
# 13         PokerAddict
# 14            Jahnster
# 15            Aaronuhh
# 16            ORAGATUN
# 17    PleaseRemainCaIm
# 18        NutterButtre
# 19                Dezú
# 20       healthy juice
# 21         Moist Swiss
# 22    lil gucci  hanni
# 23             suchham
# 24               ceveN
# 25       AntiHamLonism
# 26            Iucanity
# 27              BDaBig
# 28         Bandle Hero
# 29         draii Vlone
# 30     Rework Volibear
# 31     svenskeren dive
# 32               Ssunj
# 33               epsum
# 34      JimmyRusslesSr
# 35     Aproprtymanager
# 36             Teasday
# 37       Warrior Doggo
# 38        saucebrother
# 39            Katakurï
# 40    WonderfulTonight
# 41             binette
# 42     illBeAtBlueBuff
# 43                neap
# 44      Frank Horrigan
# 45               Kosen
# Name: EMERALD IV, dtype: object, 0         sneakypatty
# 1      YOUR PAPA CHOW
# 2     Team Player Ted
# 3     TAO BAN AD M IM
# 4          serfmirage
# 5           zbenja168
# 6     TRUMPLOVESLGBTQ
# 7        kang haerins
# 8           ZGGDZJJim
# 9      martin mystere
# 10             Zombro
# 11           Waltzy21
# 12             Argun0
# 13        c plus girl
# 14        Uzi Prodigy
# 15               4NZX
# 16           rishtarn
# 17         Metadaptor
# 18    KykyDoYouLoveMe
# 19      GOAT GREATEST
# 20              Khail
# 21          poro mate
# Name: EMERALD III, dtype: object, 0               Eonirs
# 1         haramslayerr
# 2              Vmikael
# 3      RuneScape Lucky
# 4           Shimadacat
# 5      DARKPEKPEKLOVER
# 6             Linsanit
# 7              whfmrhs
# 8             swobblee
# 9         PTG Valkyrie
# 10    UXwxJeguBM0ILeuw
# 11              Xetvan
# 12     SpyderMillipede
# 13          JaysTilted
# 14    wïnter is coming
# 15        JhussyJhuice
# Name: EMERALD II, dtype: object, 0        Shirøyasha
# 1       No Name PLS
# 2          ImDrippy
# 3            Makrae
# 4    chang yuanying
# 5      EnemyBrawler
# 6           Kryecho
# 7     HAIL AND KILL
# 8       Evełynn Bot
# Name: EMERALD I, dtype: object, 0         Broken Feng
# 1              PMA JG
# 2            DmnSword
# 3      OceanGate FFed
# 4            Moonchaa
# 5        penguinszero
# 6     Ewok Fornicator
# 7            PakuXero
# 8       beyond inting
# 9     GarryDokenhimer
# 10          Kilicuary
# 11     PeriwinkleStar
# 12       SPOOKY HORSE
# 13         DeadSpartn
# 14             Jundal
# 15         skdaniel2k
# Name: DIAMOND IV, dtype: object, 0              La1n
# 1         Btown TOP
# 2       TaxEvader33
# 3             Hòrse
# 4    Jasondingduong
# 5            RLAero
# 6           LoganZ2
# 7      DoggoTheGabe
# Name: DIAMOND III, dtype: object, 0         THICCDUMPER
# 1     SylphieRoxyEris
# 2              Mimick
# 3           O1de Town
# 4    RagingRookie5757
# Name: DIAMOND II, dtype: object, 0        rovref
# 1    Warbil Fan
# 2      Pika1106
# Name: DIAMOND I, dtype: object, 0    Kaleos
# Name: MASTER I, dtype: object, 0    ScaryJerry
# Name: GRANDMASTER I, dtype: object, 0    jin tui wei gu
# Name: CHALLENGER I, dtype: object]

# %%
names_df.to_csv('final_summoner_names.csv', sep=',', index=False) # Export to CSV
