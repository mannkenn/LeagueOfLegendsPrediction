# %%
import requests
import time
import random
import pandas as pd
import seaborn as sns

df = pd.read_csv(r"C:\Users\toirt\LeagueOfLegendsPrediction\notebooks\final_summoner_names.csv")
api_key = "RGAPI-dad742de-85d2-4c4f-9beb-8cf48db7de96"
api_url = "https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name"
for column in df.columns:
    pp = df[column].dropna()
    pp.tolist()
    print(pp[0:5])

def get_puuid(api_key, api_url, summoner_name):
    puuid_url = "%s/%s?api_key=%s" % (api_url, summoner_name, api_key)
    resp = requests.get(puuid_url)
    data = resp.json()
    return data
    
puuids = []
for name in pp:
    print(name)
    puuids.append(get_puuid(api_key, api_url, name)['puuid'])
    print(puuids)
    
    
    
# poop = get_puuid(api_key, api_url)
# Out:
# 0        rhadoo
# 1        BlùMew
# 2       3nderrr
# 3    Sleepy Ned
# 4     Zulu42069
# Name: IRON IV, dtype: object
# 0    Soggywaffles196
# 1         togaparty1
# 2       SeriousVirgo
# 3        Marraxus101
# 4     Noxian Assault
# Name: IRON III, dtype: object
# 0            nairb82
# 1       PastelStorms
# 2    TheBeachedHippo
# 3     Android Apollo
# 4    ripemNleavethem
# Name: IRON II, dtype: object
# 0     OneRiserSlip
# 1    OneLazyDaoist
# 2        NichoBack
# 3     CACA MONSTER
# 4       AxelHazaki
# Name: IRON I, dtype: object
# 0    A Bronze Klug
# 1      Snappington
# 2           K3nnyG
# 3           mystıc
# 4       Ziphor1476
# Name: BRONZE IV, dtype: object
# 0      Rentedcoffee8
# 1    Ultrachampion02
# 2             Curiyy
# 3       BangTuEsMort
# 4          songcraft
# Name: BRONZE III, dtype: object
# 0    MattRock314
# 1    DioBrando57
# 2       cashen95
# 3      bigddom21
# 4       N0ctis97
# Name: BRONZE II, dtype: object
# 0       Ajapril34487
# 1            Zeqhyrs
# 2            Spandex
# 3    Into the Spiral
# 4               Twïn
# Name: BRONZE I, dtype: object
# 0         DivineRune
# 1       EPICGAMER429
# 2       BamBam124684
# 3    TentacleQueenie
# 4            Therak1
# Name: SILVER IV, dtype: object
# 0        Starlight03
# 1              Masön
# 2        MagikCungFu
# 3    boythekiller102
# 4        Trichiosoma
# Name: SILVER III, dtype: object
# 0      xSlayer442x
# 1        OhSoCLean
# 2    Darkfrost1415
# 3           Aksyel
# 4        SacredOaf
# Name: SILVER II, dtype: object
# 0          King Dill
# 1          DonaldI2I
# 2        Silv3rfruit
# 3       ItsMeLuigi69
# 4    AlanButUnhinged
# Name: SILVER I, dtype: object
# 0              DUBW1Z
# 1               Wyätt
# 2    ALEXMASTER101010
# 3    Jhamburgr Jheþer
# 4          Tinmonkey1
# Name: GOLD IV, dtype: object
# 0    MoonMorrigan
# 1    NYC Kevin888
# 2         Alainxz
# 3    TheTopFather
# 4    KrumpuSChisG
# Name: GOLD III, dtype: object
# 0            Âxêl
# 1      T1NG light
# 2       Dreamer35
# 3       Disttance
# 4    VIETNAMGAMER
# Name: GOLD II, dtype: object
# 0         aquaticruin
# 1             Kahloon
# 2           shinylyte
# 3    Toùch My Lantern
# 4             ASALAD2
# Name: GOLD I, dtype: object
# 0            zared123
# 1    I decide not you
# 2              Aestra
# 3          timein8tor
# 4             JL Payn
# Name: PLATINUM IV, dtype: object
# 0           Ted Cundy
# 1        smegma steve
# 2    Powerful Dragon2
# 3           easy path
# 4         abedejong52
# Name: PLATINUM III, dtype: object
# 0            p8107
# 1            Têddy
# 2      StinkyBallz
# 3    ShadowRaids27
# 4           SirMRC
# Name: PLATINUM II, dtype: object
# 0         Sidesteper
# 1       MooMooMilk69
# 2    RainbowThunder7
# 3          SgSgamer1
# 4              slrpp
# Name: PLATINUM I, dtype: object
# 0    lIIllIlIIlIllIIl
# 1        Penguinlords
# 2           Ancâlagon
# 3              Synpai
# 4         SpoopyChina
# Name: EMERALD IV, dtype: object
# 0        sneakypatty
# 1     YOUR PAPA CHOW
# 2    Team Player Ted
# 3    TAO BAN AD M IM
# 4         serfmirage
# Name: EMERALD III, dtype: object
# 0             Eonirs
# 1       haramslayerr
# 2            Vmikael
# 3    RuneScape Lucky
# 4         Shimadacat
# Name: EMERALD II, dtype: object
# 0        Shirøyasha
# 1       No Name PLS
# 2          ImDrippy
# 3            Makrae
# 4    chang yuanying
# Name: EMERALD I, dtype: object
# 0       Broken Feng
# 1            PMA JG
# 2          DmnSword
# 3    OceanGate FFed
# 4          Moonchaa
# Name: DIAMOND IV, dtype: object
# 0              La1n
# 1         Btown TOP
# 2       TaxEvader33
# 3             Hòrse
# 4    Jasondingduong
# Name: DIAMOND III, dtype: object
# 0         THICCDUMPER
# 1     SylphieRoxyEris
# 2              Mimick
# 3           O1de Town
# 4    RagingRookie5757
# Name: DIAMOND II, dtype: object
# 0        rovref
# 1    Warbil Fan
# 2      Pika1106
# Name: DIAMOND I, dtype: object
# 0    Kaleos
# Name: MASTER I, dtype: object
# 0    ScaryJerry
# Name: GRANDMASTER I, dtype: object
# 0    jin tui wei gu
# Name: CHALLENGER I, dtype: object
# jin tui wei gu
# ['WaWEb0hrOYM2QkrNH6_JoG_MlU5Hgu1nkCK1_C7Ox1iPy7r91eRGgDCJQK6r2BNk88ui2PdvrxTjwg']
